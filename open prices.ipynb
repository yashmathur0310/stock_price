# %%
import yfinance as yf
import pandas as pd 
import numpy as np

# %%
import yfinance as yf 
dataset= yf.download("RELIANCE.NS",interval='1d',start='2016-11-01',end='2021-11-01')
dataset=dataset.drop(['Adj Close','Volume'],axis=1)
dataset
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close
# Date
# 2016-11-01   520.714172   523.017334   518.782471   520.565552
# 2016-11-02   515.612488   516.528809   505.706421   507.068512
# 2016-11-03   507.118042   512.516846   505.508301   507.167572
# 2016-11-04   505.334930   508.628723   495.304993   498.053955
# 2016-11-07   502.239258   503.502289   494.834473   495.874603
# ...                 ...          ...          ...          ...
# 2021-10-25  2680.000000  2680.000000  2570.000000  2601.800049
# 2021-10-26  2617.100098  2668.899902  2603.149902  2661.050049
# 2021-10-27  2652.000000  2676.800049  2619.949951  2627.399902
# 2021-10-28  2620.000000  2637.949951  2590.500000  2598.600098
# 2021-10-29  2596.149902  2596.149902  2501.699951  2536.250000
#
# [1234 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
plt.figure(figsize=(12,6))
dataset['Open'].plot()
plt.title("Opening price of Reliance")
# Out:
# Text(0.5, 1.0, 'Opening price of Reliance')
