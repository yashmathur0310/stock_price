# %%
import yfinance as yf
import pandas as pd 
import numpy as np

# %%
df=yf.download("RELIANCE.NS",interval='1d',start="2016-11-01",end="2021-11-01")
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2016-11-01   520.714172   523.017334   518.782471   520.565552   507.237732
# 2016-11-02   515.612488   516.528809   505.706421   507.068512   494.086243
# 2016-11-03   507.118042   512.516846   505.508301   507.167572   494.182770
# 2016-11-04   505.334930   508.628723   495.304993   498.053955   485.302490
# 2016-11-07   502.239258   503.502289   494.834473   495.874603   483.178925
# ...                 ...          ...          ...          ...          ...
# 2021-10-25  2680.000000  2680.000000  2570.000000  2601.800049  2601.800049
# 2021-10-26  2617.100098  2668.899902  2603.149902  2661.050049  2661.050049
# 2021-10-27  2652.000000  2676.800049  2619.949951  2627.399902  2627.399902
# 2021-10-28  2620.000000  2637.949951  2590.500000  2598.600098  2598.600098
# ...

# %%
from statsmodels.tsa.filters.hp_filter import hpfilter

# %%
df_cycle,df_trend=hpfilter(df['Open'],lamb=13322500)

# %%
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
plt.figure(figsize=(15,8))
df['Open'].plot(label='Actual Price')
df_trend.plot(label='HP filter Analysis')
df_cycle.plot(label='Residuals')
plt.legend()
